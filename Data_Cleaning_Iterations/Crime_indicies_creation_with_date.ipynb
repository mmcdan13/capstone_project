# %%
# Dependancies
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import citipy
import datetime

# %%
#Loading Files
chicago_pop_zip_data_to_load = os.path.join("Resources","Chicago_Population_by_Zipcode_2020.csv" )
crime_zip_data_to_load = os.path.join("Resources", "clean_pop_zip_model_with_date.csv")

# %%
crime_zip_df = pd.read_csv(crime_zip_data_to_load, header=0, delim_whitespace=False)
crime_zip_df
# Out:
#         Unnamed: 0    ZIP  Ward             Date                Primary Type  \
# 0                0  60601    27   1/9/2020 18:55                       THEFT
# 1                1  60601    27   1/9/2020 13:00             CRIMINAL DAMAGE
# 2                2  60601    27   1/9/2020 18:00                       THEFT
# 3                3  60601    27   1/9/2020 15:15                 SEX OFFENSE
# 4                4  60601    27   1/9/2020 17:10                   NARCOTICS
# ...            ...    ...   ...              ...                         ...
# 105624      105624  60661    30  7/17/2020 18:00               OTHER OFFENSE
# 105625      105625  60661    30    7/6/2020 4:00         MOTOR VEHICLE THEFT
# 105626      105626  60661    30   7/17/2020 7:00  OFFENSE INVOLVING CHILDREN
# 105627      105627  60661    30  7/17/2020 22:00                     BATTERY
# 105628      105628  60661    30   7/17/2020 4:05                     ROBBERY
#
#         rankings   Latitude  Longitude  Arrest  Domestic Population  \
# 0              3        NaN        NaN   False     False      5,591
# 1              4  41.883932 -87.679964   False     False      5,591
# 2              3  41.896569 -87.636063   False     False      5,591
# 3              3  41.883937 -87.683368    True     False      5,591
# 4              4  41.892856 -87.710137    True     False      5,591
# ...          ...        ...        ...     ...       ...        ...
# 105624         3  41.941430 -87.737110   False      True      4,382
# 105625         6        NaN        NaN   False     False      4,382
# 105626         3  41.940857 -87.728919   False     False      4,382
# 105627         4  41.940049 -87.719873   False      True      4,382
# 105628         8  41.923901 -87.771157   False     False      4,382
#
#        People/Sq.Mile National Rank
# 0           17,101.15          #271
# 1           17,101.15          #271
# 2           17,101.15          #271
# 3           17,101.15          #271
# 4           17,101.15          #271
# ...               ...           ...
# 105624      15,455.28          #318
# 105625      15,455.28          #318
# 105626      15,455.28          #318
# 105627      15,455.28          #318
# 105628      15,455.28          #318
#
# [105629 rows x 13 columns]

# %%
clean_crime_zip_df = crime_zip_df.rename(columns={"rankings": "crime_severity"})
clean_crime_zip_df
# Out:
#         Unnamed: 0    ZIP  Ward             Date                Primary Type  \
# 0                0  60601    27   1/9/2020 18:55                       THEFT
# 1                1  60601    27   1/9/2020 13:00             CRIMINAL DAMAGE
# 2                2  60601    27   1/9/2020 18:00                       THEFT
# 3                3  60601    27   1/9/2020 15:15                 SEX OFFENSE
# 4                4  60601    27   1/9/2020 17:10                   NARCOTICS
# ...            ...    ...   ...              ...                         ...
# 105624      105624  60661    30  7/17/2020 18:00               OTHER OFFENSE
# 105625      105625  60661    30    7/6/2020 4:00         MOTOR VEHICLE THEFT
# 105626      105626  60661    30   7/17/2020 7:00  OFFENSE INVOLVING CHILDREN
# 105627      105627  60661    30  7/17/2020 22:00                     BATTERY
# 105628      105628  60661    30   7/17/2020 4:05                     ROBBERY
#
#         crime_severity   Latitude  Longitude  Arrest  Domestic Population  \
# 0                    3        NaN        NaN   False     False      5,591
# 1                    4  41.883932 -87.679964   False     False      5,591
# 2                    3  41.896569 -87.636063   False     False      5,591
# 3                    3  41.883937 -87.683368    True     False      5,591
# 4                    4  41.892856 -87.710137    True     False      5,591
# ...                ...        ...        ...     ...       ...        ...
# 105624               3  41.941430 -87.737110   False      True      4,382
# 105625               6        NaN        NaN   False     False      4,382
# 105626               3  41.940857 -87.728919   False     False      4,382
# 105627               4  41.940049 -87.719873   False      True      4,382
# 105628               8  41.923901 -87.771157   False     False      4,382
#
#        People/Sq.Mile National Rank
# 0           17,101.15          #271
# 1           17,101.15          #271
# 2           17,101.15          #271
# 3           17,101.15          #271
# 4           17,101.15          #271
# ...               ...           ...
# 105624      15,455.28          #318
# 105625      15,455.28          #318
# 105626      15,455.28          #318
# 105627      15,455.28          #318
# 105628      15,455.28          #318
#
# [105629 rows x 13 columns]

# %%
__csv('Resources/cleaned_crime.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23332\1908861854.py in <module>
# ----> 1 __csv('Resources/cleaned_crime.csv')
#
# NameError: name '__csv' is not defined

# %%
clean_crime_df.info()

# %%
clean_crime_df.nunique(dropna=False)

# %%
crime_table = pd.pivot_table(clean_crime_df,values='crime_severity', index=['ZIP', 'Primary Type'],
                    aggfunc=np.sum)
crime_table

# %%
crime_table.reset_index()

# %%
# pivot table example with multiple aggregating functions
crime_table3_df = pd.pivot_table(clean_crime_df, values='crime_severity',
                    index='Primary Type',
                     columns='ZIP',
                     aggfunc='sum')
crime_table3_df

# %%
crime_table2_df = pd.pivot_table(clean_crime_df,  index = 'ZIP', 
                   aggfunc= 'sum')

crime_table2_df

# %%
crime_table2_df.describe()

# %%
crime_table2_df =crime_table2_df.rename_axis('index1').reset_index()
crime_table2_df

# %%
crime_table2_df.to.csv("Resources/crime_severity_summary.csv")

# %%
# read in population/zip data into a df for merging
pop_zip_df = pd.read_csv(chicago_pop_zip_data_to_load, header=0, delim_whitespace=False)
pop_zip_df

# %%
# reduce columns to what is needed
clean_pop_df = pop_zip_df[["ZIP", "Population", "People/Sq.Mile"]]
clean_pop_df

# %%
#write cleaned data to a .csv
clean_pop_df.to_csv('Resources/clean_pop.csv')

# %%
# Merging crime and population data
crime_table2_df.set_index('ZIP', inplace = True)
clean_pop_df.set.index('ZIP', inplace = True)


crime_sum_df = pd.merge(crime_table2_df, clean_pop_df,left_index=True, right_index=True, how = 'inner')
crime_sum_df.reset_index('index',drop=False, inplace=True)

crime_sum_df

# %%
#write final table to .csv
Crime_Indicies_df.to.csv(Crime_Indicies.csv)
