# %%
# Dependancies
import pandas as pd
import os

# %%
# Loading Files"
chipotle_locations_to_load = os.path.join("Resources","chipotle_stores.csv")
crime_data_to_load = os.path.join("Resources","2020_crime.csv")

# %%
#create panda dataframes
chipotle_location_df = pd.read_csv(chipotle_locations_to_load)
chipotle_location_df
# Out:
#              state          location  \
# 0          Alabama            Auburn
# 1          Alabama        Birmingham
# 2          Alabama        Birmingham
# 3          Alabama        Birmingham
# 4          Alabama           Cullman
# ...            ...               ...
# 2624     Wisconsin  Pleasant Prairie
# 2625     Wisconsin         Wauwatosa
# 2626  North Dakota             Fargo
# 2627  North Dakota             Fargo
# 2628       Wyoming          Cheyenne
#
#                                              address   latitude   longitude
# 0             346 W Magnolia Ave Auburn, AL 36832 US  32.606813  -85.487328
# 1              300 20th St S Birmingham, AL 35233 US  33.509721  -86.802756
# 2             3220 Morrow Rd Birmingham, AL 35235 US  33.595581  -86.647437
# 3           4719 Highway 280 Birmingham, AL 35242 US  33.422582  -86.698279
# 4          1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134  -86.841220
# ...

# %%
chipotle_location_df.count()
# Out:
# state        2629
# location     2629
# address      2629
# latitude     2629
# longitude    2629
# dtype: int64

# %%
chipotle_location_df.dropna()
# Out:
#              state          location  \
# 0          Alabama            Auburn
# 1          Alabama        Birmingham
# 2          Alabama        Birmingham
# 3          Alabama        Birmingham
# 4          Alabama           Cullman
# ...            ...               ...
# 2624     Wisconsin  Pleasant Prairie
# 2625     Wisconsin         Wauwatosa
# 2626  North Dakota             Fargo
# 2627  North Dakota             Fargo
# 2628       Wyoming          Cheyenne
#
#                                              address   latitude   longitude
# 0             346 W Magnolia Ave Auburn, AL 36832 US  32.606813  -85.487328
# 1              300 20th St S Birmingham, AL 35233 US  33.509721  -86.802756
# 2             3220 Morrow Rd Birmingham, AL 35235 US  33.595581  -86.647437
# 3           4719 Highway 280 Birmingham, AL 35242 US  33.422582  -86.698279
# 4          1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134  -86.841220
# ...

# %%
crime_df = pd.read_csv(crime_data_to_load)
crime_df
# Out:
#               ID Case Number             Date  \
# 0       11946909    JD109980   1/9/2020 14:25
# 1       11946915    JD110189   1/9/2020 16:58
# 2       11946931    JD110284   1/9/2020 20:25
# 3       11946971    JD109951   1/9/2020 15:53
# 4       11947070    JD110194   1/9/2020 18:46
# ...          ...         ...              ...
# 110947  12109636    JD301817   7/17/2020 0:00
# 110948  12109063    JD300997   7/17/2020 0:00
# 110949  12114564    JD307110  6/18/2020 11:47
# 110950  12108793    JD300858  7/17/2020 17:38
# 110951  12108363    JD300205   7/17/2020 6:45
#
#                                       Block  IUCR         Primary Type  \
# 0                       059XX S ASHLAND AVE   910  MOTOR VEHICLE THEFT
# 1                       076XX S STEWART AVE   610             BURGLARY
# 2                      012XX S MICHIGAN AVE  1154   DECEPTIVE PRACTICE
# 3                          048XX W RACE AVE   486              BATTERY
# ...

# %%
crime_df.count()
# Out:
# ID                      110952
# Case Number             110952
# Date                    110952
# Block                   110952
# IUCR                    110952
# Primary Type            110952
# Description             110952
# Location Description    110397
# Arrest                  110952
# Domestic                110952
# Beat                    110952
# District                110952
# Ward                    110949
# Community Area          110952
# FBI Code                110952
# X Coordinate            110201
# Y Coordinate            110201
# Year                    110952
# Updated On              110952
# Latitude                110201
# Longitude               110201
# Location                110201
# dtype: int64

# %%
crime_df.dropna()
# Out:
#               ID Case Number             Date  \
# 0       11946909    JD109980   1/9/2020 14:25
# 1       11946915    JD110189   1/9/2020 16:58
# 3       11946971    JD109951   1/9/2020 15:53
# 4       11947070    JD110194   1/9/2020 18:46
# 5       11947098    JD110266   1/9/2020 18:30
# ...          ...         ...              ...
# 110946  12109943    JD302200  7/17/2020 19:00
# 110947  12109636    JD301817   7/17/2020 0:00
# 110948  12109063    JD300997   7/17/2020 0:00
# 110950  12108793    JD300858  7/17/2020 17:38
# 110951  12108363    JD300205   7/17/2020 6:45
#
#                                       Block  IUCR         Primary Type  \
# 0                       059XX S ASHLAND AVE   910  MOTOR VEHICLE THEFT
# 1                       076XX S STEWART AVE   610             BURGLARY
# 3                          048XX W RACE AVE   486              BATTERY
# 4       043XX S DR MARTIN LUTHER KING JR DR  143A    WEAPONS VIOLATION
# ...
